# %% [markdown]
# # System Design
#
#
# ## Facebook Core values
#
#     1 Be BOLD
#     2 focus on impact
#     3 move fast
#     4 Be Open
#     5 Build social value

# %%
# 16- 24
14 days 


# 16- 18
3 System Design

    all High scalability problems
    all educative problems
    
# 18- 20
5 ML system Design
    2 - days at least 10 Researchpaper from FB
    1 - Resume projects and proper
    1 - Stats revision


5 coding and revision
    
2 - revise

# %%
'''

• Familiarity with complex systems.
• Concurrency 
    - threads, 
    - deadlock, 
    - starvation, 
    - consistency, 
    - coherence).
• Abstraction (
    - understanding how OS,
    - filesystem, 
    - and database works).
• Real-world performance (
    - relative performance RAM, 
    - disk, your network, 
    - SSD).
• Availability and reliability (
    - durability,
    - understanding how things can fail).
    
• Data storage (RAM vs. durable storage, compression, byte sizes).
• Byte math

'''

# %%
'''

## Concepts to remember

    1. QFS - quick file system ( shared storage systems  ex: MySQL, FC, NFS)
            1 writer
            multi reader ( for reading load)
    2. RAID0 hard disk - RAID10 ( single writes - multiple reads)
            mainly for cache (2 identical strip data at once and backup disks) 
            Striping breaks data into “chunks” that are written in succession to different disks (improves read performance at atime multiple)
            
    3. Memcache 
            ( key value storage mechanism, CDN)
    4. Cache 
            ( a portion of db fast accessing to processor- also needs garbage collection)
    5. Microservices 
            ( humar communication with API - Distributed app using containers)
    6. Message Queues
            ( load greater than server capacity even after LB- queue to process with limited queue count)

    #FACEBOOK used
    
    7. RTMP - Real time Messaging protocol
            (a tcp based protocol streams avi- from phone to live server - lower end to end latency - RTMP proxy required)
    8. MPEG - DASH : Dynamic Adaptive streaming over HTTP
            (allows adaptive bit rates encoding quality can be varied based on n/w)
    9. POP - point of presence ( Facebook CDNs) 
            ( Predict POPs ( CDNs) load also prior and redirect to nearest to reduce latency.
    10. Horizontal Scaling
            Cetralized scaling, Decentralized scaling, Fully Distributed scaling
    
    # TWITTER
    
    11.Mediald
        Media gateway with keys and transcoding features( Image Bird, Video BIRD) - Segmented ids reliable uploads
        
    # SALESFORCE
    
    12. Instance
            a complete set of systems N/W and storage infra ex. wabco-audo.salesforce.com
    13. superpod( supports multiple instances)
            instance includes with Proxy server, SAN fabric, LB, mail server, other - supporting multiple instances
    14. Org
            single customer of SF app. customizable with UI look, workflows, triggers, custom objects, REST APIs
    15. Sandbox
            instance that hosts full copies of production, development process.
    16. Cursor
            a mechanism that enables traversal over the records a database Cursors facilitate subsequent processing 
            in conjunction with the traversal, such as retrieval, addition and removal of database records
    17. ACS-API cursor search (QFS)
            ACS is a cursor cache running on pair of servers. Providing a method to offload cursor processing from DB tier.
            single writer 
            multiple reader
        
    18. IBM eXtreme scale
            Distributed in-memory hash map.
    19. Routers
            Routers are also used for port forwarding between private Internet-connected servers. 
            Voice, data, fax, and video processing routers: Commonly referred to as access servers or gateways, 
    20. Firewalls
            A firewall is a system designed to prevent unauthorized access to or from a private network.
    21. CDN
            Content Delivery Networkds
            
    # GOOGLE
    
    22. GFS (google file system)
            1k-5k machines, ~5pb data processing,
            across nodes, GFS cluster, Huge R/W bandwidth
    23. BigTable
            Distributed hash mechanism on top of GFS, not RDB, doesn't support Queries SQL
            3 servers like Map reduce
                Master server - assign tablets to tablet server - tracks where tablets located and redistributed if needed.
                Tablet Server - process R/W requests for tablets. split tablets when limit exceeds(100-200 mb)
                Lock Server   - Openning table for writing, Master arbitration, access control checking, mutual exclusion.
            tablets cached  as possible
    24. Gearman, 
            a job queue system, is used for long running fire and forget type work.
    25. Redis(like memcache)
            In- Memory data structure store- used as distributed key value DB(cache)
            When deciding whether to use Redis or Memcached a major difference between these two is data persistence. 
            While Redis is an in-memory (mostly) data store and it is not volatile, Memcached is an in-memory cache and it is volatile
    26. ZooKeeper 
            is a centralized service for maintaining configuration information, naming, providing distributed 
                synchronization, and providing group services
            To get how far packets, segments, data have read by consumer
    27. HDFS- hadoop distributed file system
            featues : Replication, end-to-end checksums, automatic load balancing, 
    28  HBase
            - scalability, performance of worklload
            - replication
            - End- to End checksum
            - Auto load balancing
            
            - HBase is a column-oriented key-value NoSQL database that can store multiple values against one key into 
            multiple columns. 
            - HBase is modeled after Google’s BigTable and runs on top of Hadoop Distributed File System (HDFS). 
            HBase groups data together to store new data in a memory buffer and, once the buffer is full, it dumps the 
            data to the disk. 
             -  helps to store a lot of small data quickly but also fetching rows by the key or 
            scanning ranges of rows. HBase is also an efficient database to store variable-sized data, 
            

    29 WebSocket 
            WebSocket is a computer communications protocol, providing full-duplex communication channels over a single 
            TCP connection. The WebSocket protocol was standardized by the IETF as RFC 6455 in 2011, and the WebSocket 
            API in Web IDL is being standardized by the W3C. WebSocket is distinct from HTTP.
            
            One Server of specific IP can open - 65000 sockets easily
            
    30 Count-Min sketch data structure
            In computing, the count–min sketch (CM sketch) is a probabilistic data structure that serves as a frequency 
            table of events in a stream of data. It uses hash functions to map events to frequencies, but unlike a hash 
            table uses only sub-linear space, at the expense of overcounting some events due to collisions.
    31 MD5 function, 
            which generates 128b long hash. out of this rake 43bits to generate tiny URL.probability of collision 
                inversely propertional to length of tiny URL
    32. Cassandra  
            a key value store always maintain certain noof relicas, deletes wont be instant
    33. NoSQL
            key value store, Data is stored in an array of key-value pairs.
            Well-known key-value stores include Redis, Voldemort, and Dynamo.
    34. TCP 
            allows transmission of both directions, send and recieve same time.
    35. SSL
            SSL Certificates are small data files that digitally bind a cryptographic key to an organization’s details.                 
            web server, it activates the padlock and the https protocol and allows secure connections from a web server to a browser
                - private key and one is called a public key.
                - domain name, server name or hostname.
                - An organizational identity (i.e. company name) and location.
    36. GraphX
            spark, ETL, transforms rdmbs to rdd
            shortest path algorithms - BFS, DFS,
    37. Matrix Factorization
            a technique of Matrix decomposition ( gradient descent )
            simple Factorization methods 
                - LU matrix decomposition ( Lower- Upper decompostion )
                - QR matrix decomposition ( A = QR, orthogonal, upper traingular )
    38 GPG check
        download files weather they are valid, to verify , only allow from trusted, external apis hash, 
            When file download, check hash key, weather the hash key inside.
    39 Bloom Filters
            Element search mechanism with specific data structure, yields all False positives
            https://www.youtube.com/watch?v=Bay3X9PAX5k  - 9.04 min
            
            
'''

# %%
'''
Pracice whiteboard sketching - Coder pad

Challenges:
    # FB
    1. Live video traffic spiky - Load Balancing
    2. Spiky Traffic puts pressure on Caching - Global load balancing (CDNs - fb points of presence POPs)
    3. Concurrent production - needs microservices
    4. to stop thunder herd use Message queues and cache.
    5. System Arch ( Responsiveness, Throughput, Load Distribution, Fault tolerance, security)
    6. Distributed (CNTK, Tensorflow, MxNet, Nvidia ncc, GCP, watson cloud, hadoop, spartk, mlib)
    7. Customer traffic starts with external DNS and input directs to appropriate Data center
    8. Check API based traffic to DB along with HTTP requests
    9. Process isolation if faulty code deploys - wont disturb others
    10. either LRU cache expiry or TTL case expiry
    11. Hibernate Query caching mechanism
    12. in hosting server cost effective with DB ratesof blob(2rs/gb/m) - 
            installation N/W cost much, firewall, Router, VPN devices, LB
            keep 1000s of rack linux(decentralised) than single reliable components server
            
    13. Non relations DBs, Hbase, redis
    14. HBase - high write requirements. (MySQL - unfit)
        MySQL problems - 
            - sharding in time series data read replication 
            - MySQL cant handle large taildata , performance suffered
            - lag due to insert inconsistency on slaves (Non relational - Graph best)
    15. Usual DB problems :
            - Auto load balancing failover,
            - compression support, 
            - multiple shards, etc
    
    16. The current scatter-gather model for providing Dashboard functionality has very limited runway
    17. Messgaes data: ever growing data rarely gets accessed., temperal data tends to be volatile.
    18. LBs withh multi armed bandits - thompson sampling - 
    19. Data Compression by counting all subsequential data and replacingwith count values and so on- reduces by 25%
    20. Image compression methods - discrete cosine transform (DCT) 
    21. Video compression methods - discrete cosine transform (DCT) and motion compensation (MC)
    22. Usually, 1 billion active users- messages-500billion/month
    23. Photos, videos - HDFS, S3 and CDN networks
    24. Region based , market based - disaster recovery
    25. Encryption, hashing, Server operation depends on bandwidth, computaiont, applicatoin db performance
    
    
    
    
    
Doubts :
    1. How RAID10 works for multipler reads
    2. what is fire and forget type work.
    3. what is firehose (data analytics, data write front cache)
    4. How cursor works in db
    5. How Web sockets are used 
    6. how Map reduce works and Hbase
    7. why ssl tcp 443
    8. 
'''

# %%
# Ports should familiar

'''
Ports accessing
tcp - transmission control protocol

# - Security                                     {Cloud}
    Cloud -> Load balancer                          |
    kind of traffic allowed    Ports                |
        - TCP Protocol         tcp-80               |
        - http based, ssl      443 (http-ssl)       |
        - SSH Port             22  (ssh)            |
    ssl termintates at Load balancer                 
                                                   
# - Load balancer -> Web servers               {Load Balancer}
    tcp80                      tcp80                |
    
# - Webserver -> DB                              {Data Base}
    SQL queries(fetch, insert) tcp3306


split load 100k req - > 100's of app load  -> 10 MLB
                            - >                    ->
                            ...                    ...
                            
                            
InHouse servers:                            
N/W equipment costly, but storage equipment cheap
Firewalls, Router, VPN devices, Load balancing

Blob storage cost
First 50 terabyte (TB) / month   ---	₹2.6513 per GB	  -  ₹1.44091 per GB	₹0.21542 per GB


-----------------------------------------------------------------------------------------------------


    Map Reduce 
            map function that processes a key/value pair to generate a set of intermediate key/value pairs, and 
            a reduce function that merges all intermediate values associated with the same intermediate key. 
            Data compressed prior transferring nodes.
             - automatically parallelized and executed on a large cluster 
             - The run-time system takes care of the details of partitioning the input data, 
             - scheduling the program's execution across a set of machines, 
             - handling machine failures, 
             - and managing the required inter-machine communication. 
            
             
             Servers :
                 Master server - assign tasks to map and reduce servers and track states
                 Map    server - perform map operations on data and store intermediate files
                 reduce server - accepts intermediate files and perform reduce operation.
                 
                 GFS -> Map -> Shuffle -> Reduction -> Store Results back into GFS
                 
             Straggler:
                 is a computation that is going slower than others which holds up everyone
                 solution is to run multiple of the same computations and when one is done kill all the rest
    BigTable
            Distributed hash mechanism on top of GFS, not RDB, doesn't support Queries SQL
            TBs of memory, PBs of storage can handle milllion of reads/ second
        
            3 servers like Map reduce
                Master server - assign tablets to tablet server - tracks where tablets located and redistributed if needed.
                Tablet Server - process R/W requests for tablets. split tablets when limit exceeds(100-200 mb)
                Lock Server   - Openning table for writing, Master arbitration, access control checking, mutual exclusion.
            tablets cached  as possible
'''

# %% [markdown]
# ## Grokking System Design

# %%
'''
Steps

    1. Requiements clarification
       -------------------------
        Ask scope of problem solving
        Questions open- ended
        Possibilities of users respective to app and outmost cases
        
    2. System Interface Defintion
       -------------------------- 
        How many Design APIs are expected 
            ex - /PostTweet(userid, tweet, timestamp,location)
                 /GenerateTimeLine(userid, timestamp, location)
                 /markTweetFavourite(userid, postid, timestamp)
                 
    3. Back of envelop estimation
       --------------------------
        Estimate scale of the system
            SCale - Noof tweets, Noof Tweet views, Noof Timeline generation
            DB    - how much storage required
                        1 char  - 1 Byte
                        1 integer - 1 bits
                        1 float   - 256 bits 
                        
    4. Defining Data Model
       -------------------
       how data will flow amont different components of system
           - Data Management, 
           - transporation, Data flow,
           - Encryption, 
           ex   User: UserID, Name, Email, DoB, CreationData, LastLogin, etc.
                Tweet: TweetID, Content, TweetLocation, NumberOfLikes, TimeStamp, etc.
                UserFollowo: UserdID1, UserID2
                FavoriteTweets: UserID, TweetID, TimeStamp
                
    5. High Level Design
     -------------------
         Block of 5-6 boxes represents core components of system
         Individual servers for individual operations.
    
    6. Detailed Design
    ------------------
        dig 2 to 3 components- Interviwer directions
            need different approaches, proc, cons
             - Data partitions, should we store all the data of user in same db, cause?
             - how will we handle hot users( who tweets a lot) ?
             - do we need to store recent like scanning of latest tweets?
             - how much and which layer should we introduce cache to speed up?
             - what components need better load balancing ?
    
    7. Identifying and resolving Bottlenecks
    ----------------------------------------
        Try giving as many bottlenecks as possible.
            - any single point of failures in system ? how to mitigate
            - do we have enough replicas of DataProcess even after data loss
            - services replicas
            - performance monitoring of service ?
            - do we get response whenever critical components fails ?
            
            
           




This editor is synced in real time with your peer.

Use it to share thoughts and resources, such as:
- Features scope
- API design
- Pseudo code for specific components
- Data model/schema
- Back-of-the-envelope calculations
- Reference links
- Link to whiteboard or diagram such as https://sketchboard.me/new

Good luck!
                
'''

# %%
# https://www.youtube.com/watch?v=VJpfO6KdyWE
# Design Twitter
'''steps :- 
    1 - Requirement gathering
        1 Upload Images from mobile client
        2 Users Follow others
        3 Genearte a feed images
        
        
        # Calculate How many requests should it handle and how much data it needs
            Ask the requirement pricesly for second - 
                facebook users - 1.3 billion
                twitter users  - 600 million - tweets per day 500million
        
            4 scale: 10 millions users
                Calculate the data required by 10mn people
                    for 2 photos per month
                        10^7 * 2* 5MB
                            10^8  100TB of storage == 1.2PB of data

                    Difficulties:
                         - How much traffic going to have
                         - What are storage requirements
                             since it is photo data need search for reliable storage method
    Deciding API or Data Model
        
        
    2 - Data Model  -   DB Schema defining :
            Tables and foreign keys and reference keys to point
             Data base Design and kinds of database to choose
            
    3 - High Level components 
        
             Meta Data Database  
             Distibuted Object storage mechanism - S3 bucket - which can be distributed file system to everyone
                 - store reference to path files in our metadata database, accessible in fast.

Test Cases=  
    What happens when it reaches 10 millions
    
    4 - Application Server :
        Different Servers Services: Caching, Load balancers, network load balancer
            Read Services 
            Upload servicss
        
    5 - Load balancers:
         Scale horizonatally 
         keeping many many app servers 
             

    '''

# %%
2. Didn't clarify on usecase
1. feedback from interviewer 
3. Map reduce for live calls. 
4. didn't mention peak load
5. Went into calculations even when bandwidth was too low - gives a sense you are not aware of bandwidth used in data centers
6. how you come up with 10ms 
7. A* algorithm / BFS
8. used tri without 
9. used technologies which is not used. 
10. limitations of service. 
11. does't know load balancer is actually not one.  - Type of load balancers
Softskills
1. talk too fast

collaborative recommenadaion
elk cate nearest businesses within radiuos
Newsfeed

# %% [markdown]
# ## Book of Content Moderation
# Useful
# https://www.ofcom.org.uk/__data/assets/pdf_file/0028/157249/cambridge-consultants-ai-content-moderation.pdf

# %%
'''
Architectures
FACEBOOK
--------
    phone sends RTMP stream to Live stream servers                                        - RTMP
    Live stream servers decodes the video and transcodes to multiple bit rates            - transcodes
    For each bit rate of set of - one second MPEG-DASH segment is continuously produced   - MPEG-DASH
    Segments are stored data centers cache                                                - Data centers cache   - One Point Multiply
    From data center cache segments are sent to caches located in Points of presences     - POPs                 - Many point Multiply
    players on their device starts fectching segments from nearest POP based on bit rate  - device
    1 user can have millions of followers
    
    Scaling:
    One point multiplication          Many Mutiplication at POP
    data center cache - POPs    ->      POPs caches ( https, Cache)
     
http://highscalability.com/blog/2016/6/27/how-facebook-live-streams-to-800000-simultaneous-viewers.html


UBER 
----
    maily migration all existing to efficient, Utilizing best for speeding productions
    
    Using Microservices 
    Open sources, Migrations
    Modularization
    Logging
    Load testing
    Ceaseless undulating traffic 
    Message Queues to handle overloaded requests
    
    Web-Sockets
    
    
    Low level Design
        
        Dispatch system at Uber - node.js
            scaling servers and services
                re-pop 
                    consistance hashing - Gossip protocol (add/remove server from ring of regions)

                     
        Building maps and paths
            Cabs nearer, and one more which is about to complete trip nearer.
        
        DB
            write and read availability 
            Kafka -> Hive -> ETA
                     hdfs 
        Analytics view in these
            
                     
http://highscalability.com/blog/2016/10/12/lessons-learned-from-scaling-uber-to-2000-engineers-1000-ser.html
https://www.youtube.com/watch?v=umWABit-wbk

Deep Learning In Production
---------------------------
    billion images at a time
    
    I/P    ->   Python API      ->   aesthetic score
                Pre processing
                Post processing
    
    Each request sequential 
    Pre-Post processing - CPU time taking
    one Batch at a time 
    
    Gate Keeping
    ------------
    API based Qs(message Qs)  - Http end poitns
    
    Isolation R and D code - Containers
    
    
    
TWITTER
-------
    Problems
        1700 tweets/sec(max 6900)  - 1billion/week - 460k new accounts/day
        1 user can have millions of followers
        
    1. Wasted N/W bandwidth - intermittent(n/w failure) - Upload, download
    2. Does't scale new large media(like transcodes)  - unreliable N/W
    3. Inefficient use of Bandwidth - Monolithic , large payloads
    4. Located storage Foot prints - No GC(garbage coll), no Blob storage
    
    1. Arch
    
    Client     ->     TFE     ->     Image Server   ->  Blob Storage  ->   Metadata
                   twitter front       post proc       
                   end
                   
    2. Mediald : Unique identifier for media -> retured to iamge
                    Interface for Media
                    in analyzation
    
    3. Flow for tweet
        
        Client -> mediald  ->  TFE   -> Video Bird
                                        Image Bird
                                        
                            route the service
                            to appropriate entity
          no media passed around lot of wasted bandwidth saved
    
    4. Segmented Resumable uploads
            client initialize upload session - backend mediald)
            with identifiers throughout the process
            image divided into segments - resilient to network failures
    
    5. MinaBird Intro
        Dynamic client          Image Bird  - image size variants
        request hanlding
                                Video Bird  - Video format variants
        easy authorization
        
        keeps cache of trending in CDN  - CDN
        TTL timeto live  - saving storage
        
    
    Introduced WEBP ( 25% smaller than jpeg, not for apple)
    Progressive JPEG ( renders photo scan fast , 60% slower)
        
    
SALESFORCE
----------
    Mainly handling 1.3 billion transactions/Day
    17 instances in NA , 4 EMEA instances, 2 APAC instances - 23 total
    20 sandbox instances, 1.3billion trans/day, 15k_ hw systems, 
    >22PB of raw SAN storage
    >5k SAN ports
    
    ARCH
    starts with external DNS and input directs to appropriate Data center
    
    Customers    ->    Pool servers           ->      home instance  ->  LB  -> Data centers
            (external    login traffic       (session)    Org
            DNS)         redirect session 
                        to home instance
    
    Inside Instance
            traffic ->  Load Balancer    -> Standard Web  
                                            page traaffic
                                            
                                         -> API Traffic (60% of app traffic)
                                         
                                         -> Additional Servers
    Core App 
        10 - 40 servers at least 14 GB cache
        Batch Servers (Orchestrator) -  Weekly Backup - Centralised system
        basic and advanced content management
            content search, content batch servers for managing asynchronous processes.
        
    Data Base (key) 
    ----------
    
            Core App   - Data Base Tier
        each primary instance uses 8 node clustered DB tier
        customers sandbox have 4 nodes clustered DB tier
        
        to reduce load on DB SF developed ACS-  API cursor search
        
        ACS-API search
            search tier commonly in linux servers 640gb PCI-E flash drive - cache layer
                
                Translation servers        ->      DB storage
                  search index         LUN mount
                                     Fiber channel SAN
                                         
            LUN - logical unit number
     
ESPN
----
problems: 
    innovatinve cable and satelite TV sport empire ( multiple sport types and their peaks)
    Usual High level scheme with pool servers, NHL, NFL,  MLB sport servers respective DBs
    
        user ->  I/N -> Page/frag     -> Front page  -> Cross sport      ->   Application level Caching(TTL)
                        caching Tier     Web cluster    Meta data
                                                        Dynamic Control system
                                                        respective DBs, (NHL, NFL, MLB)
                                                        
    Hibernate
        100s of 100s of Qs
        Ehcache for second level of cache for entity updates(TTl wont work, not optimal)
        The Hibernate Query caching mechanish  - JPA
        
    CMS- Content Management system
        2 Subsystems
            - CMS  -   Highly ptimized querying, Ful RDB, 100s of editors  
            - DCS dynamic content system  -  stored as blob, edited data goes to CMS, DCS
            
    Live Scores
        Web socket for seb socket existed
        Flash Connector - can handle 100k concurrent open socket connections
    Distributed memory hash map
    special effects - NVIDIA GPU solution for high resolution imagery, - Each gpu for i/p, o/p i/o comput engine
    
    
GOOGLE
------
    sorting 1 PB - 1m GB ~ 6.20 hours (4k computers, thrice replications)
    100k MapReduce jobs ~ 20pm data processing /day
    Stats
        900k  low cost servers          21 data centers
        130   trillion pages            200 GFS clusters ( each cluster 0 5pb of data)
        0-10k Mapreduce Opera
    Products
        Search, advertising, email, maps, videos, chat, blogs
    Distributed System Infra 
        GPS, Mapreduce and Big Table ( high read opr, storage on GS, SStable,  clubby lock service)
    
    Map Reduce 
        map function that processes a key/value pair to generate a set of intermediate key/value pairs, and 
        a reduce function that merges all intermediate values associated with the same intermediate key. 
        Data compressed prior transferring nodes.
         - automatically parallelized and executed on a large cluster 
         - The run-time system takes care of the details of partitioning the input data, 
         - scheduling the program's execution across a set of machines, 
         - handling machine failures, 
         - and managing the required inter-machine communication. 

    BigTable
        Distributed hash mechanism on top of GFS, not RDB, doesn't support Queries SQL 
        TBs of memory, PBs of storage can handle milllion of reads/ second
        3 servers like Map reduce
            Master server - assign tablets to tablet server - tracks where tablets located and redistributed if needed.
            Tablet Server - process R/W requests for tablets. split tablets when limit exceeds(100-200 mb)
            Lock Server   - Openning table for writing, Master arbitration, access control checking, mutual exclusion.
        tablets cached  as possible
            
    1000s  folded infra better than 2 reliable compenents infra
        Linus rack inhours design, PC class mother boaerds, mix of allocatoin own data centers
        
        
        
TUMBLER
-------
     - Front-end layer uses HAProxy. Varnish might be hit for public blogs. 40 machines.
     - 500 web servers running Apache and their PHP application.
     - 200 database servers. Many database servers are used for high availability reasons. Commodity hardware 
       is used an the MTBF is surprisingly low. Much more hardware than expected is lost so  there are many 
       spares in case of failure.
     - 6 backend services to support the PHP application. A team is dedicated to develop the backend services.
     - A new service is rolled out every 2-3 weeks. Includes dashboard notifications, dashboard secondary index, 
       URL shortener, and a memcache proxy to handle transparent sharding.


FACEBOOK messaging service
--------------------------
    - 2.6 billion users - 60mil p-p msgs/month  ~  620 bi msgs/month atleast
    short set of temporal data tends to be volatile
    ever growing set of data rarely gets accessed.
    
    - checked Cassandra   - consitency key valued search, ,
    - checked MySQL       - Cant handle large tails of data, perormance suffered, multiple shards
    - Aparch HBase        - chosen, NoSQL 
    
    HBase
        - scalability, performance of worklload
        - replication
        - End- to End checksum
        - Auto load balancing
        

    
'''

# %% [markdown]
# ## Examples

# %% [markdown]
# ## Tiny URL

# %%
## Desin a Tiny URL system

'''
    Requirements:
         - Gives you a URL and bring the tiny url id associated with it
         - Need API interface to bring the Tiny URL associated with it

         - Links will expire after a standard default timespan. Users should be able to specify the expiration time
         - Users should optionally be able to pick a custom short link for their URL

    APIs 
        RestAPI 
            /ShortenURL
            /FetchURl
    
    Stats:
        Data DB
        -------
        url with length of 7 characters
            Combinations a-z - 26
                         A-Z - 26
                         0-9 - 10
                         62**7 - combinations to be exausted -calculate accordingly
            
            Assure 500 Million new URLs /month
                per Year 500M * 256 Bytes
                         5 * 25 GB -  125GB
                         125 gb * 12 - 1.5 TB
        Memory
            if follow 80-20 rule 
                    80 % traffic
                    20 % url generates
                    
            20k requests/second   = 24* 20k 
                                    = 1720 milllion req/day
                                    
            to cache 20% all requests  = 1720 M * 500 
                            since there will be duplicates - 
            
                            
        NewURLS    - 200/s
        traffic    - 20k/s
        incoming data- 100KB/s
        outgoing data- 100KB/s
        total db    - 15TB
        cache       -170GB
         
            DB table  schema ( USER, URL table) - NoSQL
                Original URL, APIdevkey, custom_alias, user_name, expire_date
            Since billion rows are there - Use NoSQL
            
            
        Bandwidth
        ---------
        write requests
         since 200 new urls/ second  
             200*500 bytes/second = 100 kbps
        read requests
         at least 20k URLs 
            20k *500 bytes/second = 10 mbps
            
            
    Ensure
        Read Heavy in Nature
        Min Latency
        Consistancy or highly available
            (count-min, )
            
    Encoding
    --------
        MD5 for unique hash base 64 encoding as( a-z, A_Z, 0-9)


        base64 will expose 64 characters to 64^6
             64^6 = ~68.7 billion possible strings.
             64^8 = ~281 trillion possible strings
        
    Key Generation Service (KGS) offline, Key generation service(LB)

    Data Partition and replication
    --------------
        range partitioning(bins of cipher, hashing function will randomly distribute URLs into different partitions)
         data into different DB servers
    Cache(LRU)
    -----
        memcached store urls with respective hashes
        How much cache memory should we have   -  20% of daily traffic   -  178 GB so get 256GB
        As estimated above, we need 170GB of memory to cache 20% of daily traffic
        
    Load Balancer
    -------------
        Between client and application
        Between application and DB
        Between Applicaiton and Cache
        
        initially round robin- problem of round robin( server load not consider)
        
    Purging  and DB cleanup
    -----------------------
        User specific Expiration
        expired links clean up- so to reduce load
        Error of expired links
        scheduled run to clean up load
        default expiration time
        utilizing the keys for expired links
    
    Telemetry
    ---------
        How many times user has been used
        user location, - store statistics
        users with distribution of usage and urls peak times
    
    Security
    --------
        permission level with each user
     
        
    Approach -1 

        Techniques to generate Tiny URL - all are with Random Tiny URL generation :

            1 : Generate random tiny URL and check 
                steps:
                    Gen on tiny URL and check if it exists in the database or not 
                        Complications: 
                            After its get the tiny URL worker tries to put tiny URL and long URL
                            same time another worker may tries to use same url and put in DB
                So, Stable production system will not deploy this technique

            2 : Put if abscent into the database:
                Relational Database like - MySQL and oracle who supports full asset properties 
                automecity, isolation, consistency for those its a trivial operation.

                For NoSQL database they might or might not suppport put is abscent.
                    advantages of NoSQL.
                        It scale well than relational databases.
                        and Oracle is expensive.
                Works, if you have database support.

            3 : Generate Random URL, put tiny and long in DB, check if long URL put is with key of tiny
                Check until long URL matches to get he put.

    Approach -2 
        MD5 function, which generates 128b long hash. out of this rake 43bits to generate tiny URL.
        probability of collision inversely propertional to length of tiny URL.

        first case two random tiny urls so 2 times space, but here same url id with hash 
            Convert 43bits Hash id to 7 charactersm 
            COnvert 43 bits binary to decimal with 2** - Numerical number
            convert rest to base 62 which is possibility letters


    Approach - 3
        Counter based approach 
            1 - Single host
                could be a DB or a Zookeeper instance

                ZooKeeper is a centralized service for maintaining configuration information, naming, 
                providing distributed synchronization, and providing group services

                Increments counter everytime new worker requests for it 

                Problem - 
                Single point of Failure and single point of bottleneck
                cant handle too many requests if it receives.

            2 - All hosts
                every host internally tries to reach the same counter

                suppose 64 bit representation in 6 bits. 
                    Assign unique 6 bits to every host and current time stamp for Unique ID which is 32 bit 
                    6 + 32 + 5 (random or incremental counter) 

                Problems :
                    If the noof requests are 1000/sec - last operation of 5 ( max possiblities 2**5 = 32) can have collision
                    to make it work  - millisecond variation of 32 and increase counter size

            3 - Range based Counter
                7 Characters with upto 3.5 trillioin combinatins
                and it scales well.

                after first 1 trillion combs splits into 1000 equal bins stored in zoo keeper
                worker 1 claims for some bin
                worker 2 claims for some bin and keep maintain a incremented Counter 
                No Collision
                if it exausts create a new more batch with Zoo keeper.

                one litter problem - security thread.



            API request for tiny url
            -> Load balancer
                -> Worker1    -> Worker2    -> Worker3 ...             ->  { Cache}

            -> -> -> -> DB

            if you want it for global usage then CDN 


'''

# %% [markdown]
# ## Pastebin

# %%
'''
    services enable users to store plain text or images over the network
    generate unique URLs to access the uploaded data
    
    Requirements
    ------------
        Functional -
            Users should upload data or paste   -  get Unique URL
            only text, url expires, users specify expiration time, custom URL requ
        Non Functional - 
            highly reliable, less latency
            available , consistant - cons
    
    Design Consideration
    --------------------
        limit of text size 
        user specific data limit for 10mb
        size limits for urls ?
    
    Capacity - stats
    ----------------
         Read - heavy
         80-20 read writes
         traffic similar to fb and twitter
         milap,ketto-  250 :1
         
                     if follow 80-20 rule 
                    80 % traffic
                    20 % url generates
                    
            20k requests/second   = 24* 20k 
                                    = 1720 milllion req/day
                                    
            to cache 20% all requests  = 1720 M * 500 
                            since there will be duplicates - 
           
                            
        NewURLS    - 200/s
        traffic    - 20k/s
        incoming data- 100KB/s
        outgoing data- 100KB/s
        total db    - 15TB
        cache       -170GB
    
    REST API
    --------
        Parameters
            parse_data
            user
            customer URL
            paste_name
            expire_data
        /getPastekey
        /deletePaste
        
    DataBase Design
    ---------------
        billion records
        each metadata object - small <1kb
        paste object would be in 1 mb
            DB schema
            User table,  - URL table(userid, content, content expiry, creatoin date)
    
    HighLevel
    ---------
    same as Tiny URL
        
        
        
## Design Instagram
===================

    social networking service that enables, users uploads photos and videos
    publicly shared, private, share through FB, Twitter, Flickr, tumblr
    
    planning for simpler version of instagram - where upload images, shares images visibility to pull out model
    
    Requirements
    ------------
        Functional Reqrs
            users should upload photo , video
            users should upload text
            users should get updates of his friends updates, can follow others
            news feed of all top celebrities
        Non functional requrs
            highly reliable 
            less latency
            avaialbe consistante
        
    stats capacity estimation
    -------------------------
        assume 1 billion users 1 million active users
            2 M new photos/day
            average photo size - 200kb
                               - 2M * 0.2MB = 400 GB
            space for 1 year   = 400*365
            
    High level
    ----------
        2 scenarios 
            upload photos aothers to view /search photos
            service needs object storage
        segregating hot accounts
    
    DB schema
    ---------
        Photo,                 User,             UserFollow,
        id,                   Name               UserId1
        photopath             Email              UserID2
        latitude              DOB
        longitude             CreationDate
        user latitude         LastLogin
        User longitude
        CreationDate
        
        USER     -   as frequent changes of joins and updates required  can opt for RDBMS
        Photos,  -   distributed space of HDFS(NoSQL), and S3  - CDN 
        Videos
                               
         Cassandra  : a key value store always maintain certain noof relicas, deletes wont be instant


        Storage
            User table
                name, dob, email,   together =  68KB
                                500M users   =  500*68    by -> kb -> mb-> gb -> tb -> pb
                                                50kB *  mill
                                                32 GB
            Photo table
                each photo - 256kb and param =  300 kb
                    2 M photos /day          =  300*2M
                                             =  0.5 GB /day
                                for 10 years =  365*10   =  5*365  = 1830GB = 1.8 tb
                                
            User follow table
                user row need 8 bytes
                
                
    Component Design
    ----------------
        
        Read heavy, most reads through CDN and cache servers
                







'''

# %%
## Design Auto complete Or Typeahead Suggestions

'''
Requirements :
    Need to complete the typed sentence
    
    constraints:
    - No personal information 
    - Concentrating only on English
    
    Solution :- 
        Distributed Trie - Word Trie 
        With ML interaction 
        top K terms for every preferences 
        
        
        
    Constraints :- 
        Trie will be very huge, millions are billions of phrases.
        Need to distribute the trie to multiple machines.
        
        2 REST APIs required
            1 - getsuggestions
            2 - addQuery
        
        Client -> Load balancer -
        ------------------------
                                
                                Load balanceres (round robin)
                                 |
        Zoo keeper instance      _
        a- $ 3 tries             N1             N2              N3
        any of this seq
        
        
        Say 3 tries 
        Distributed Cache
        Say Memcache            T1             T2              T3
            backup Tries
            if 1 dies
            or 1 lost
            
        
        memcache interactions to each request and store
        
        To expand it on large trie data. 
        A-K would go to Trie1 and rest to Trie2 and Trie 3
        
                                         
        Zoo keeper instance      _
        a - K 3 tries T(1,2,3)         N1             N2              N3
        K - $ 3 tries T(4,5,6) 
        any of this seq
        
        
        Say 3 tries 
        Distributed Cache
        Say Memcache                  T1             T2              T3
            backup Tries
            if 1 dies                 T4             T5              T6
            or 1 lost

        If the load increases much, we can split it to multiple tries
    
    
    Collecting Data
    
    Data Collection Flow
    --------------------
    one way -> API   phrase - weight 
            -> save to DB
            -> Aggregate (either consistencey or modular based cache)
            
    DB used - cassandra ( NoSQL databaase)
    
    
    Schema: 
        Phrase   |   Time       | Sum of weights
        bas         timeslots      11015
        bat         of 
                    2am to 3am
                    3am to 4am 
                    
    Need CDN at all places to supply requied, . all possible pass through CDN than revert to DB
    

'''

# %%
# Payment Gateway system
# FB inbox search
# Design a interface to search post from facebook wall feed  https://www.careercup.com/question?id=6201187863887872
# How to design Github
# we have server and database what if response time is slow, how to optimize ?
# takes lattitude and longitude returns cloest 5locations

# Design candy crush saga board with mxn boardwith q types of candies

# critique google maps and yelp
# design a library book rental delivery app

# %%
# Top 10 system design questions asked at Facebook

# How would you design Instagram / Instagram Stories
# How would you design Facebook
# How would you design Facebook Messenger
# How would you design Facebook's live update of comments on posts
# How would you design an online collaborative editor (e.g. Google Docs)
# How would you design a typehead feature (e.g. Google search autocomplete)
# How would you design Twitter's trending topics
# How would you design a distributed Botnet
# How would you design a system that can handle millions of card transactions per hour
# How would you design security for Facebook's corporate network from scratch (Security team interview)

# %%
## Important things to gather and discuss

# gathering requirements,
# defining protocol, 
# high-level design, 
# database schema, 
# data size estimation, 
# component design, and tradeoffs

# %% [markdown]
# Product Development Concepts:
#
#
#         1 - Customer Identity Principle
#         2 - Market as Need Principle
#         3 - Product management scope
#         4 - The Whole Problem
#         5 - Product Management Toolkit
#         6 - Product Management Business Definitions
#         7 - Product Management Recap
#         8 - Roles and goals
#         9 - PMTK model echelon model
#         10- Market Research
#         11- Market Usecases
#         12- PSFB Problem, solution, features, benefits
#              Product Delivery process
#             Key Documents( MRD, PRD, Technical specifications)

# %% [markdown]
# Sample
# https://www.youtube.com/watch?v=VJpfO6KdyWE
#
# https://www.facebook.com/careers/life/preparing-for-your-software-engineering-interview-at-facebook
#
#
#
#
# https://www.facebook.com/careers/ML-prep-initial
#
# https://www.facebook.com/careers/ML-prep-onsite
#
#
# https://www.hiredintech.com/classrooms/system-design/lesson/53

# %% [markdown]
# ### Micro Services
# https://avinetworks.com/glossary/microservice/
#
# ### Cortex XD

# %%
'''

ML application Deployment methods


 - Vertical scaling
 - Horizontal scaling
 - Caching
 - Load balancing
 - Database replication
 - Database partitioning
 
 

Deployment methods used:
●	Worked with utilizing the Azure Web services in generating API key and to deploy the Analytical solutions. 
●	Consolidating analytical solutions to containers and Executable files for bash execution servers.
●	Creating a separate local python environment on the server to access analytical solutions
    for server hosted Web applications.
●	Containerizing a separate local Analytics environment on the docker server to access analytical 
    solutions through containers.
    Explored understanding of AWS ML platform, Azure AI gallery and Salesforce Einstein AI platform.
●	Customize wrapping of analytical operations to Skills in CORTEX XDR platform to bring elastic 
    load balancing in large production data handling.




'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Concepts should be familiar,
# 1. Load balancing
#         Mainly balancing the traffic to each machine and figuring which machine is offline and removing traffic from that machine
#        types ( route the client request to number of ofther web servers( we can setup how should it work) (
#
#         Application Load Balancer
#         Network Load Balancer
#         Classic Load Balancer
#
# !<img style="float: right;" src="attachment:image.png" width="500"/>
#
#       <b>techniques:</b>
#
#           Nginx
#           DNS load balancing ( given URL website, you
#           can have that website resolve to number of
#           different IP addresses)
#
#                   You dont need any other machines,
#                   ( cant have much customization as well
#
#
#
# <blockquote> Usually Web server is not first to go down <b>Data Base is under highload to godown often</b> </blockquote>
#
#
#     Hitting data Base hard, for lots of writes and reads, bunch of sequel joins and queries which needs some Caching layer
#
#     Cache for 24 hours or more
#
#     Common caching services are
#             memcache,  cassandra
#             also content delivery networks
#
#
#
#
# !<img style="float: right;" src="attachment:image-2.png" width="500"/>

# %% [markdown]
# ## CDN - Content Delivery Networks to cache static and asset files
#
# !<img style="float: right;" src="attachment:image.png" width="500"/>
#
#       -  Like Images, Javascript files, htmls CSS, Video
#       files( usually all video files served through CDN
#       which is a global network
#       -  People around the world can access the data
#       without even hitting the DB, it wont hit down
#       servers, CDNs allows super fast accessing of data
#       and these are located geographically nearly to the
#       people all acroos the world.
#
#       POOL Setup
#       -  CDNs easy to setup one common technique using
#       Pool setup( the first use is slowly to fetch, but
#       next after for the user and for the region people
#       it would be fast
#
#       PUSH Setup
#       -  It would be fast even for the first time users,
#       but higher upfront cost to store files in CD and other
#
#
#  - If you like to users to upload images, then you need Distributed File System( Amazon S3)

# %% [markdown]
# ## Design Data Base schema what tables you use
#
# !<img style="float: right;" src="attachment:image.png" width="500"/>
#
#     What table would you like to use,
#     Primary keys, importance of them
#
#     If your data base id under high load , keep a
#     slave - master(copy of data base) replication,
#     where you only read from. replicate it from another host
#     machine
#
#
#
#
#
# Consistency:
#
#         If you write it to data base then you immediately read back from DB.
#         Usual apps have 2-3 seconds
#
# ##  Handling too many Data base writes - Data base Sharding.
#
# !<img style="float: right;" src="attachment:image-2.png" width="300"/>
#
#
#
#     Where you split up the data base into multiple
#     master database
#
#     Tehcniques:
#
#         Vertical Sharding
#
#         Harizontal Sharding
#            If we have single table of large size
#
#            ( take user ID and modify it by the
#             total number of machines you want
#             allocate it to)
#
#
#
#
# !<img style="float: right;" src="attachment:image-3.png" width="300"/>
#
# !<img style="float: left;" src="attachment:image-4.png" width="500"/>
#
#
# !<img style="float: left;" src="attachment:image-5.png" width="800"/>

# %% [markdown]
# ## Number of techniques for scaling out Web Application Server
#
#     Usually we have
#         -- Web Server
#                 Load Balancers - you can add as many load balancers you want
#
#         -- Data Base server
#                 Caching
#                 Data Replication
#
#         -- Image Server or Asset Server, Video Server --
#                 CDN content delivery network ( Scale to thousounds of machines around the world)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
#     - Ask clarficatioin questions
#     - check out your assumptions weather ri8 or not :-|
#     - Keep talking and communicate what you are doing
#     - practice solving questions with a time limit without executing code.
#     - focus on working solution then get best solution ( Done is better than perfect ).
#     - propose test cases to test solution properly.
#
#
#
#    - Prepare Key points to convey about you
#    - Be specific about what you have done ( Contribution of you )
#
#
#    System Design
#
#        ML Oriented, Machine learning best experience
#
#         best experience for users.
#         best streaming topics
#         program generalist
#          ApI, pipelines, system design
#
#
#          Can you design Spotify or messenger( clear our what you are best at, how you google it what you interested to bring rirst)

# %%
## System Design Questions and flow

# %% [markdown]
# ## Machine Learning Design

# %%
'''

BERT understading
Transformers ( RNNs)
    RNN  - processing language sequentially in a left-to-right or right-to-left fashio
    Attention MEchanism explained - Attention is all you need.
    
Give High level Understanding then statistical Phenominon of improving
    
GANs
'''

# %%
# https://towardsdatascience.com/introduction-to-recommender-systems-6c66cf15ada
'''
Recommendation Engine types
    1. Content based Filtering,
    2. Collaborative filitering
        - Memory based recommendation
            - User-User  = common interactions ( +ve, -ve , -)
            - Item -Item = positively interacted wih  (KNN)
            
                * Memory based approaches directly works with values of recorded interactions, 
                  assuming no model, and are essentially based on nearest neighbours search
                Nearest Neighbour

                as no latent model theoretically 
                      - Low Bias 
                      - High Variance
        - Model based recommendation
                The model is trained to reconstruct user-item interactions values from its own representation of users and items. 
                 latent representations extracted by the model have a mathematical meaning that can be hard to interpret a human being
                      - High Bias
                      - Low Variance
                  
                  
    3. Hybrid recommendatoin


    
    Recommendation Engine work
        - Collection of data
        - Storing data
        - Aalyzing data
        - Filtering data
        
    Requirements
    -------------
        Functional
            Create more traffic and interaction between users.
            Provide related/relevant posts, materials based on users information.
            Increase customer satisfaction.
            Increase revenue due to marketing effeciency. As modern marketing is all about data

        Reverse Engineering
            1. Facebook should pay close attention to the information posted on user’s accounts more than 
            the validity of the account in itself
            2. Recommendation of new friends should not be based on check in places. It should be based on user’s location or city.
            3. Use key words to identify and filter people’s interests. This will help the recommendation in more accurate way. 
                For example, Some people like pages but they don’t have a strong interest in the page content. 

            4. The excess amount of groups on FB should be limited.

    Collaborative Filtering
    -----------------------
        If the data is too sparse like 0.5% then collaboartive filtering not best idea to choose
        
        Worth choosing, new users and newitems - it wont work for new users or users (need content based or hybrid)
        
        Algorithms to implement Matrix Factorization 
        
            - Singular value decomposition (SVD)
            - Alternative Lease Squares (ALS)
            - Stachastic Gradient Descent (SGD)
           
        
        -  Popular Evaluation Matrix for Recommender systems
           -------------------------
            - Precision @K
                basically works on top K recommendations and find propertion of relevant recommendations for user
                
        - HyperParameters Tuning(breadth search, Gradients)
         -----------------------
             for Alternating Least Squares algorithm (ALU)
                 k (factors),
                 l lambda (regularization parameter)
                 
                 ex - k=8 and l=0.2 gave good
         
         - Apply Similarity methods like Cosine Similarity to get recommendation
         
         Evaluation 
         ----------
             Test ab testing, Usability testing, topK precision
        
        Considerations
            Interpretability
            Efficiency, scalability, Diversity, Serendipity
        
                 
        
    Approach - Matrix Factorization
    ===============================
        - Singular Value Decomposition
        -------------------------------
        It just a PCA , dimensionality reduction technique with placing some random origin based vecors in 
        Item dimensionality space and calculating the distance from points, which is magnittude of singular values.
        
        Iterative approach of choosing feature vector and iteratest to get optimal,
            After some noof iterations changes in features vectors become small, convergence
        
        item1, item2                       Weights 
            [       ]     =~   u1  [     ]           E        * item1 [            ]
            [       ]          u2  [     ]                      item2                          =~  Actual Memory based Matrix
            [       ]          u3  [     ]  
                    U*I                  U*F        F*F                  F*I
            
        
         Matrix Factorization
         ---------------------
         Alternating Least Squares ( 2 steps optimization -  fixes U, solves I and fixes I and solves U)
         
                a technique of Matrix decomposition ( gradient descent )
                simple Factorization methods 
                    - LU matrix decomposition ( Lower- Upper decompostion )
                    - QR matrix decomposition ( A = QR, orthogonal, upper traingular )
                    
                    
        matrix factorization is commonly used for collaborative filtering
            - User Factor Matrix
            - Item Factor Matrix
                                item1, item2                       Weights 
            [       ]     =~   u1  [     ]            * item1 [            ]
            [       ]          u2  [     ]                      item2                          =~  Actual Memory based Matrix
            [       ]          u3  [     ]  
                    U*I                  U*F                        F*I
             user*Item     User (Boolean Weights      *  interests( Optimised weights 
                                 of users)                       for Items)
                    
            Find short 
            similarity indexes
            
        
         - The main advantage of collaborative approaches is that they require no information about users or items 
         - “Cold start problem”: it is impossible to recommend anything to new users or to recommend a new item to 
             any users and many users or items have too few interactions to be efficiently handled
                 : eliminated by recommendeing Random
                 
                Content based models suffer less with cold start problem
            
                 
            collaborative filtering approaches: 
                two memory based methods (user-user and item-item) and 
                one model based approach (matrix factorisation).
        Model based
        -----------
                 Items weight
                 User- item interaction matrix
        Optimize SVD, or Model
        ----------------------
            check the group size of each item and place in effective group
            

        Models, bias and variance
        -------------------------
            
        
             
            
'''
